# %% [markdown]
# # KNN Algorithm -K -nearest algorithm

# %%
import seaborn as sns
Iris=sns.load_dataset('Iris') #online dataset fetching

# %%
Iris.shape
# Out:
# (150, 5)

# %%
Iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
Iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
Iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import matplotlib.pyplot as plt
species=['setosa','versicolor','virginica']
color=['blue','orange','green']
for i in range(3):
    f = Iris[Iris['species'] == species[i]] ##forming sub dataframe
    #print (f)
    plt.scatter(f['sepal_length'],f['petal_length'])

# %%
sns.set_style('whitegrid')

# %%
sns.FacetGrid(Iris,hue='species',height=6).map(plt.scatter,'sepal_length','petal_length').add_legend()

# %%
Iris.corr() #to define corelation(-1 to 1) between
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
corr = Iris.corr()
fig,ax = plt.subplots(figsize=(5,5))
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(Iris)

# %%
X = Iris.iloc[:,:4]  #X=Iris.drop(columns='species') ##removing independent variable

# %%
Y=Iris.iloc[:,-1] #Y=Iris['species']

# %%
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# # Feature Scaling-to do standardizatisation,preprocessing is done

# %%
#scaling using standardization or normalisation
#standardization mean=0 ,sd=1
#normalization min to max value 0,1 respectively
#when difference in units of data, feature scaling and pre processing is performed, for obtaining more accuracy

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
ss.fit(X) #training
# Out:
# StandardScaler()

# %%
X_ss=ss.transform(X)

# %%
X_ss
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
import pandas as pd
X_std=pd.DataFrame(X_ss,columns=['sepal_length','sepal_width','petal_length','petal_width'])

# %%
X_std
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0       -0.900681     1.019004     -1.340227    -1.315444
# 1       -1.143017    -0.131979     -1.340227    -1.315444
# 2       -1.385353     0.328414     -1.397064    -1.315444
# 3       -1.506521     0.098217     -1.283389    -1.315444
# 4       -1.021849     1.249201     -1.340227    -1.315444
# ..            ...          ...           ...          ...
# 145      1.038005    -0.131979      0.819596     1.448832
# 146      0.553333    -1.282963      0.705921     0.922303
# 147      0.795669    -0.131979      0.819596     1.053935
# 148      0.432165     0.788808      0.933271     1.448832
# 149      0.068662    -0.131979      0.762758     0.790671
#
# [150 rows x 4 columns]

# %%
X_std.describe().round(2)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count        150.00       150.00        150.00       150.00
# mean          -0.00        -0.00         -0.00        -0.00
# std            1.00         1.00          1.00         1.00
# min           -1.87        -2.43         -1.57        -1.45
# 25%           -0.90        -0.59         -1.23        -1.18
# 50%           -0.05        -0.13          0.34         0.13
# 75%            0.67         0.56          0.76         0.79
# max            2.49         3.09          1.79         1.71

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()

# %%
mms.fit(X)
# Out:
# MinMaxScaler()

# %%
X_mms = mms.transform(X)

# %%
X_mms
# Out:
# array([[0.22222222, 0.625     , 0.06779661, 0.04166667],
#        [0.16666667, 0.41666667, 0.06779661, 0.04166667],
#        [0.11111111, 0.5       , 0.05084746, 0.04166667],
#        [0.08333333, 0.45833333, 0.08474576, 0.04166667],
#        [0.19444444, 0.66666667, 0.06779661, 0.04166667],
#        [0.30555556, 0.79166667, 0.11864407, 0.125     ],
#        [0.08333333, 0.58333333, 0.06779661, 0.08333333],
#        [0.19444444, 0.58333333, 0.08474576, 0.04166667],
#        [0.02777778, 0.375     , 0.06779661, 0.04166667],
#        [0.16666667, 0.45833333, 0.08474576, 0.        ],
#        [0.30555556, 0.70833333, 0.08474576, 0.04166667],
#        [0.13888889, 0.58333333, 0.10169492, 0.04166667],
#        [0.13888889, 0.41666667, 0.06779661, 0.        ],
#        [0.        , 0.41666667, 0.01694915, 0.        ],
#        [0.41666667, 0.83333333, 0.03389831, 0.04166667],
#        [0.38888889, 1.        , 0.08474576, 0.125     ],
# ...

# %%
X_nor = pd.DataFrame(X_mms,columns=['sepal_length','sepal_width','petal_length','petal_width'])

# %%
X_nor
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0        0.222222     0.625000      0.067797     0.041667
# 1        0.166667     0.416667      0.067797     0.041667
# 2        0.111111     0.500000      0.050847     0.041667
# 3        0.083333     0.458333      0.084746     0.041667
# 4        0.194444     0.666667      0.067797     0.041667
# ..            ...          ...           ...          ...
# 145      0.666667     0.416667      0.711864     0.916667
# 146      0.555556     0.208333      0.677966     0.750000
# 147      0.611111     0.416667      0.711864     0.791667
# 148      0.527778     0.583333      0.745763     0.916667
# 149      0.444444     0.416667      0.694915     0.708333
#
# [150 rows x 4 columns]

# %%
X_nor.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       0.428704     0.440556      0.467458     0.458056
# std        0.230018     0.181611      0.299203     0.317599
# min        0.000000     0.000000      0.000000     0.000000
# 25%        0.222222     0.333333      0.101695     0.083333
# 50%        0.416667     0.416667      0.567797     0.500000
# 75%        0.583333     0.541667      0.694915     0.708333
# max        1.000000     1.000000      1.000000     1.000000

# %%
sns.pairplot(X)

# %%
sns.pairplot(X_std)

# %%
sns.pairplot(X_nor)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_std,Y,test_size=0.3,random_state=1)

# %%
X_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 14      -0.052506     2.169988     -1.453901    -1.315444
# 98      -0.900681    -1.282963     -0.430828    -0.130755
# 75       0.916837    -0.131979      0.364896     0.264142
# 16      -0.537178     1.939791     -1.397064    -1.052180
# 131      2.492019     1.709595      1.501645     1.053935
# 56       0.553333     0.558611      0.535409     0.527406
# 141      1.280340     0.098217      0.762758     1.448832
# 44      -0.900681     1.709595     -1.056039    -1.052180
# 29      -1.385353     0.328414     -1.226552    -1.315444
# 120      1.280340     0.328414      1.103783     1.448832
# 94      -0.294842    -0.822570      0.251221     0.132510
# 5       -0.537178     1.939791     -1.169714    -1.052180
# 102      1.522676    -0.131979      1.217458     1.185567
# 51       0.674501     0.328414      0.421734     0.395774
# 78       0.189830    -0.362176      0.421734     0.395774
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
kmodel = KNeighborsClassifier(n_neighbors=3)

# %%
kmodel.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_predict = kmodel.predict(X_test)

# %%
y_predict
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'virginica',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'setosa', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'setosa', 'versicolor', 'virginica', 'versicolor'],
#       dtype=object)

# %%
y_test
# Out:
# 14         setosa
# 98     versicolor
# 75     versicolor
# 16         setosa
# 131     virginica
# 56     versicolor
# 141     virginica
# 44         setosa
# 29         setosa
# 120     virginica
# 94     versicolor
# 5          setosa
# 102     virginica
# 51     versicolor
# 78     versicolor
# 42         setosa
# 92     versicolor
# 66     versicolor
# 31         setosa
# 35         setosa
# 90     versicolor
# 84     versicolor
# 77     versicolor
# 40         setosa
# 125     virginica
# 99     versicolor
# 33         setosa
# 19         setosa
# 73     versicolor
# 146     virginica
# 91     versicolor
# 135     virginica
# 69     versicolor
# 128     virginica
# 114     virginica
# 48         setosa
# 53     versicolor
# 28         setosa
# 54     versicolor
# 108     virginica
# 112     virginica
# 17         setosa
# 119     virginica
# 103     virginica
# 58     versicolor
# Name: species, dtype: object

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_predict)

# %%
acc
# Out:
# 0.9777777777777777

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_predict)

# %%
cm
# Out:
# array([[14,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  1, 12]], dtype=int64)

# %%
cm1 = pd.DataFrame(cm,columns=['setosa','versicolor','virginica'],index=['setosa','versicolor','virginica'])

# %%
cm1
# Out:
#             setosa  versicolor  virginica
# setosa          14           0          0
# versicolor       0          18          0
# virginica        0           1         12

# %%
from sklearn.tree import DecisionTreeClassifier
DTModel = DecisionTreeClassifier()

# %%
DTModel.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict_dt = DTModel.predict(X_test)

# %%
y_predict_dt
# Out:
# array(['setosa', 'versicolor', 'versicolor', 'setosa', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'versicolor', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'setosa', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'virginica',
#        'versicolor', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'setosa', 'versicolor', 'setosa', 'versicolor', 'virginica',
#        'virginica', 'setosa', 'versicolor', 'virginica', 'versicolor'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
acc = accuracy_score(y_test,y_predict_dt)

# %%
acc
# Out:
# 0.9555555555555556

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_predict)

# %%
cm
# Out:
# array([[14,  0,  0],
#        [ 0, 18,  0],
#        [ 0,  1, 12]], dtype=int64)
