# %% [markdown]
# # Target

# %%
##Show the relationship between working age population,old population and young population of USA

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r'C:\Users\User\Downloads\Indicators.csv')
data
# Out:
#         CountryName CountryCode  \
# 0        Arab World         ARB
# 1        Arab World         ARB
# 2        Arab World         ARB
# 3        Arab World         ARB
# 4        Arab World         ARB
# ...             ...         ...
# 5656453    Zimbabwe         ZWE
# 5656454    Zimbabwe         ZWE
# 5656455    Zimbabwe         ZWE
# 5656456    Zimbabwe         ZWE
# 5656457    Zimbabwe         ZWE
#
#                                              IndicatorName      IndicatorCode  \
# 0        Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 1        Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 2        Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 3        Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 4              Arms exports (SIPRI trend indicator values)     MS.MIL.XPRT.KD
# ...                                                    ...                ...
# ...

# %%
data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', 'Year',
#        'Value'],
#       dtype='object')

# %%
data['CountryCode'].unique()
# Out:
# array(['ARB', 'CSS', 'CEB', 'EAS', 'EAP', 'EMU', 'ECS', 'ECA', 'EUU',
#        'FCS', 'HPC', 'HIC', 'NOC', 'OEC', 'LCN', 'LAC', 'LDC', 'LMY',
#        'LIC', 'LMC', 'MEA', 'MNA', 'MIC', 'NAC', 'OED', 'OSS', 'PSS',
#        'SST', 'SAS', 'SSF', 'SSA', 'UMC', 'WLD', 'AFG', 'ALB', 'DZA',
#        'ASM', 'ADO', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW', 'AUS', 'AUT',
#        'AZE', 'BHS', 'BHR', 'BGD', 'BRB', 'BLR', 'BEL', 'BLZ', 'BEN',
#        'BMU', 'BTN', 'BOL', 'BIH', 'BWA', 'BRA', 'BRN', 'BGR', 'BFA',
#        'BDI', 'CPV', 'KHM', 'CMR', 'CAN', 'CYM', 'CAF', 'TCD', 'CHI',
#        'CHL', 'CHN', 'COL', 'COM', 'ZAR', 'COG', 'CRI', 'CIV', 'HRV',
#        'CUB', 'CUW', 'CYP', 'CZE', 'DNK', 'DJI', 'DMA', 'DOM', 'ECU',
#        'EGY', 'SLV', 'GNQ', 'ERI', 'EST', 'ETH', 'FRO', 'FJI', 'FIN',
#        'FRA', 'PYF', 'GAB', 'GMB', 'GEO', 'DEU', 'GHA', 'GRC', 'GRL',
#        'GRD', 'GUM', 'GTM', 'GIN', 'GNB', 'GUY', 'HTI', 'HND', 'HKG',
# ...

# %%
data1=data['CountryCode'].str.contains('USA')
USA_DATA=data[data1]
USA_DATA
# Out:
#            CountryName CountryCode  \
# 22220    United States         USA
# 22221    United States         USA
# 22222    United States         USA
# 22223    United States         USA
# 22224    United States         USA
# ...                ...         ...
# 5655831  United States         USA
# 5655832  United States         USA
# 5655833  United States         USA
# 5655834  United States         USA
# 5655835  United States         USA
#
#                                              IndicatorName      IndicatorCode  \
# 22220    Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# 22221    Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 22222    Age dependency ratio, old (% of working-age po...     SP.POP.DPND.OL
# 22223    Age dependency ratio, young (% of working-age ...     SP.POP.DPND.YG
# 22224    Alternative and nuclear energy (% of total ene...  EG.USE.COMM.CL.ZS
# ...

# %%
adr=USA_DATA['IndicatorName'].str.contains('Age dependency ratio')
adr=USA_DATA[adr]
adr
# Out:
#            CountryName CountryCode  \
# 22221    United States         USA
# 22222    United States         USA
# 22223    United States         USA
# 48688    United States         USA
# 48689    United States         USA
# ...                ...         ...
# 5527274  United States         USA
# 5527275  United States         USA
# 5637254  United States         USA
# 5637255  United States         USA
# 5637256  United States         USA
#
#                                              IndicatorName   IndicatorCode  \
# 22221    Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 22222    Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL
# 22223    Age dependency ratio, young (% of working-age ...  SP.POP.DPND.YG
# 48688    Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 48689    Age dependency ratio, old (% of working-age po...  SP.POP.DPND.OL
# ...                                                    ...             ...
# ...

# %%
op=adr['IndicatorName'].str.contains('old')
op=adr[op]
yp=adr['IndicatorName'].str.contains('young')
yp=adr[yp]
wp=adr['IndicatorName'].str.contains('Age dependency ratio')
wp
# Out:
# 22221      True
# 22222      True
# 22223      True
# 48688      True
# 48689      True
#            ...
# 5527274    True
# 5527275    True
# 5637254    True
# 5637255    True
# 5637256    True
# Name: IndicatorName, Length: 165, dtype: bool

# %%
wp=adr-op-yp
wp=wp[wp]
wp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...
